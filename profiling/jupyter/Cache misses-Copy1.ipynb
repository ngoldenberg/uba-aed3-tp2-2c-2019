# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
df = pd.read_csv('../results/bruteforce_random_cases.csv')

# %%
plt.clf()
axis1 = plt.subplot(2,1,1)
df.plot(x='instance_index', y='algorithm_time', kind='density', ax=axis1)
axis1.legend(['Costos aleatorios'])
axis1.set_ylabel('Densidad')
axis1.set_xlabel('Tiempo')
plt.show()

# %%
df = pd.read_csv('../results/cost_variation_low_nk.csv')

# %%
plt.clf()
axis1 = plt.subplot(2,1,1)
df.plot(x='iteration', y='time_1', kind='density', ax=axis1)
df.plot(x='iteration', y='time_2', kind='density', ax=axis1)
df.plot(x='iteration', y='time_3', kind='density', ax=axis1)
axis1.legend(['Experimento 1', 'Experimento 2', 'Experimento 3'])
axis1.set_ylabel('Densidad')
axis1.set_xlabel('Tiempo')
plt.show()

# %%
df = pd.read_csv('../results/cost_variation_high_nk.csv')

# %%
plt.clf()
axis1 = plt.subplot(2,1,1)
df.plot(x='iteration', y='time_1', kind='density', ax=axis1)
df.plot(x='iteration', y='time_2', kind='density', ax=axis1)
df.plot(x='iteration', y='time_3', kind='density', ax=axis1)
axis1.legend(['Experimento 1', 'Experimento 2', 'Experimento 3'])
axis1.set_ylabel('Densidad')
axis1.set_xlabel('Tiempo')
plt.show()
